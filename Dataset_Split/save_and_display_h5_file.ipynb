# %%
import os
import h5py
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

def read_h5_file(file_path):
    with h5py.File(file_path, 'r') as h5_file:
        keys = list(h5_file.keys())
        print("Keys in the H5 file:", keys)
        
        # Assuming the first key is for the image and the second key is for the mask
        image_key = keys[0]
        mask_key = keys[1]
        
        image = np.array(h5_file[image_key])
        mask = np.array(h5_file[mask_key])
        return image, mask, image_key, mask_key

def convert_to_uint8(image):
    # Normalize the image to the range [0, 255]
    image_min = image.min()
    image_max = image.max()
    image = (image - image_min) / (image_max - image_min) * 255
    return image.astype(np.uint8)

def save_image(image, save_path):
    img = Image.fromarray(image)
    img.save(save_path)

def display_and_save_image_and_mask(image, mask, save_dir, file_name):
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.title('Brain MRI Image')
    plt.imshow(image, cmap='gray')

    plt.subplot(1, 2, 2)
    plt.title('Tumor Mask')
    plt.imshow(mask, cmap='gray')

    plt.tight_layout()
    save_path = os.path.join(save_dir, f"{file_name}.png")
    plt.savefig(save_path)
    plt.close()

def process_and_save_h5_files(source_dir, target_parent_dir, generate_reference=False):
    target_image_dir = os.path.join(target_parent_dir, 'images')
    target_mask_dir = os.path.join(target_parent_dir, 'masks')
    reference_dir = os.path.join(target_parent_dir, 'reference')

    if not os.path.exists(target_image_dir):
        os.makedirs(target_image_dir)
    if not os.path.exists(target_mask_dir):
        os.makedirs(target_mask_dir)
    if generate_reference and not os.path.exists(reference_dir):
        os.makedirs(reference_dir)

    for root, dirs, files in os.walk(source_dir):
        for file in files:
            if file.endswith('.h5'):
                file_path = os.path.join(root, file)
                image, mask, image_key, mask_key = read_h5_file(file_path)

                # Convert to uint8
                image = convert_to_uint8(image)
                mask = convert_to_uint8(mask)

                # Define save paths
                file_name = os.path.splitext(file)[0]
                image_save_path = os.path.join(target_image_dir, f"{file_name}.png")
                mask_save_path = os.path.join(target_mask_dir, f"{file_name}.png")

                # Save the image and mask
                save_image(image, image_save_path)
                save_image(mask, mask_save_path)

                # Display and save the reference image if required
                if generate_reference:
                    display_and_save_image_and_mask(image, mask, reference_dir, file_name)

                print(f"Processed and saved: {file}")

# Example usage
source_dir = r'C:\Users\lewka\Downloads\archive\brats'
target_parent_dir = r'C:\Users\lewka\Downloads\processed_brats'
generate_reference = False  # Set to False if you don't want to generate reference images
process_and_save_h5_files(source_dir, target_parent_dir, generate_reference)
# Out:
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_001_60.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_001_61.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_001_62.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_001_63.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_001_64.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_001_65.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_001_66.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_001_67.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_001_68.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_001_69.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_001_70.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_001_71.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_001_72.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_001_73.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_001_74.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_001_75.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_100.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_101.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_102.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_103.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_104.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_105.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_106.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_107.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_108.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_69.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_70.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_71.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_72.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_73.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_74.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_75.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_76.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_77.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_78.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_79.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_80.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_81.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_82.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_83.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_84.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_85.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_86.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_87.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_88.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_89.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_90.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_91.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_92.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_93.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_94.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_95.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_96.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_97.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_98.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_003_99.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_100.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_101.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_102.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_103.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_104.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_79.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_80.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_81.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_82.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_83.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_84.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_85.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_86.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_87.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_88.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_89.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_90.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_91.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_92.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_93.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_94.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_95.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_96.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_97.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_98.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_004_99.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_48.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_49.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_50.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_51.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_52.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_53.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_54.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_55.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_56.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_57.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_58.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_59.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_60.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_61.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_62.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_63.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_64.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_65.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_66.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_67.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_68.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_69.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_70.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_71.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_72.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_73.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_74.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_75.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_76.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_77.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_78.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_79.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_80.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_81.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_82.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_83.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_84.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_85.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_86.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_87.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_88.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_89.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_008_90.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_100.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_101.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_102.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_103.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_104.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_105.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_106.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_107.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_62.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_63.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_64.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_65.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_66.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_67.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_68.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_69.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_70.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_71.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_72.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_73.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_74.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_75.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_76.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_77.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_78.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_79.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_80.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_81.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_82.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_83.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_84.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_85.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_86.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_87.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_88.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_89.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_90.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_91.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_92.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_93.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_94.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_95.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_96.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_97.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_98.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_009_99.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_100.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_101.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_102.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_103.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_104.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_105.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_106.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_107.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_108.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_109.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_110.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_111.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_112.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_113.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_114.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_115.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_116.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_117.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_118.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_119.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_120.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_121.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_86.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_87.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_88.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_89.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_90.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_91.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_92.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_93.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_94.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_95.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_96.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_97.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_98.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_011_99.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_100.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_101.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_102.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_103.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_104.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_105.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_106.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_107.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_108.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_109.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_67.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_68.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_69.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_70.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_71.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_72.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_73.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_74.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_75.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_76.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_77.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_78.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_79.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_80.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_81.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_82.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_83.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_84.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_85.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_86.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_87.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_88.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_89.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_90.h5
# Keys in the H5 file: ['x', 'y']
# Processed and saved: BRATS_015_91.h5
